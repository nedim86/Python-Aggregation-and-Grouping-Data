# %% [markdown]
# # Agregating Data - crosstab()

# %%
import pandas as pd
data_BM=pd.read_csv('big_mart_sales.csv')
# Replace missing values
data_BM.loc[(data_BM.Item_Weight.isna() == True) , 'Item_Weight'] = round(data_BM.Item_Weight.mean(),3)
data_BM.loc[(data_BM.Outlet_Size.isna() == True) , 'Outlet_Size'] = 'Medium'
data_BM
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# Total number of rows and columns of data frame data_BM
data_BM.shape
# Out:
# (8523, 12)

# %% [markdown]
# # EXAMPLE 1 ( crosstab() )

# %%
# Apply crosstab() over the 'Outlet_Size' and 'Outlet_Location_Type' columns
# The default aggregate function for crosstab() is count (counts rows for columns defined in crosstab)
# margins = True - adds summed values for columns and rows
pd.crosstab(data_BM['Outlet_Size'], data_BM['Outlet_Location_Type'],
            margins=True, margins_name="Total")
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3  Total
# Outlet_Size
# High                       0       0     932    932
# Medium                   930    1855    2418   5203
# Small                   1458     930       0   2388
# Total                   2388    2785    3350   8523

# %%
# Apply crostab () without margins = True and margins_name
pd.crosstab(data_BM['Outlet_Size'],data_BM['Outlet_Location_Type'])
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3
# Outlet_Size
# High                       0       0     932
# Medium                   930    1855    2418
# Small                   1458     930       0

# %% [markdown]
# # EXAMPLE 2 ( crosstab() )

# %%
# Overview of the initial data frame data_BM
data_BM
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# We want to calculate the number (frequency) of products per group 'Item_Type' in each group 'Outlet_Size'
pd.crosstab(data_BM['Outlet_Size'],data_BM['Item_Type'], margins=True, margins_name="Total")
# Out:
# Item_Type    Baking Goods  Breads  Breakfast  Canned  Dairy  Frozen Foods  \
# Outlet_Size
# High                   73      25         13      65     80            92
# Medium                388     155         67     395    404           515
# Small                 187      71         30     189    198           249
# Total                 648     251        110     649    682           856
#
# Item_Type    Fruits and Vegetables  Hard Drinks  Health and Hygiene  \
# Outlet_Size
# High                           142           23                  61
# Medium                         762          141                 323
# Small                          328           50                 136
# Total                         1232          214                 520
#
# Item_Type    Household  Meat  Others  Seafood  Snack Foods  Soft Drinks  \
# Outlet_Size
# High               103    41      16        5          125           49
# ...

# %%
# We want to calculate the number (frequency) of products per group 'Outlet_Size' in each group 'Item_Type' 
# Identical results as in the previous example, only a different display of rows and columns
pd.crosstab(data_BM['Item_Type'], data_BM['Outlet_Size'], margins=True, margins_name="Total")
# Out:
# Outlet_Size            High  Medium  Small  Total
# Item_Type
# Baking Goods             73     388    187    648
# Breads                   25     155     71    251
# Breakfast                13      67     30    110
# Canned                   65     395    189    649
# Dairy                    80     404    198    682
# Frozen Foods             92     515    249    856
# Fruits and Vegetables   142     762    328   1232
# Hard Drinks              23     141     50    214
# Health and Hygiene       61     323    136    520
# Household               103     550    257    910
# Meat                     41     265    119    425
# Others                   16      98     55    169
# Seafood                   5      39     20     64
# Snack Foods             125     740    335   1200
# Soft Drinks              49     270    126    445
# Starchy Foods            19      91     38    148
# Total                   932    5203   2388   8523

# %% [markdown]
# # EXAMPLE 3 ( crosstab() )

# %%
# Load data from the new orders.xls file into the data frame orders_data
orders_data = pd.read_excel("orders.xls")

# %%
orders_data
# Out:
#       Row ID  OrderID Order Date Order Priority  Order Quantity       Sales  \
# 0          1        3 2010-10-13            Low               6    261.5400
# 1         49      293 2012-10-01           High              49  10123.0200
# 2         50      293 2012-10-01           High              27    244.5700
# 3         80      483 2011-07-10           High              30   4965.7595
# 4         85      515 2010-08-28  Not Specified              19    394.2700
# ...      ...      ...        ...            ...             ...         ...
# 8394    7765    55558 2010-08-09         Medium               8   1294.0400
# 8395    7766    55558 2010-08-09         Medium              23    392.5700
# 8396    7906    56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907    56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914    56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
# Total number of rows and columns of data frame orders_data
orders_data.shape
# Out:
# (8399, 21)

# %% [markdown]
# # EXAMPLE 3.1.

# %%
# Apply crosstab () by columns 'Province' and 'Customer Segment'
pd.crosstab(orders_data['Province'], orders_data['Customer Segment'], 
            margins=True)
# Out:
# Customer Segment       Consumer  Corporate  Home Office  Small Business   All
# Province
# Alberta                     214        276          167             208   865
# British Columbia            191        415          298             222  1126
# Manitoba                    201        310          160             122   793
# New Brunswick                91         86           84              62   323
# Newfoundland                 20         30           14              18    82
# Northwest Territories        33        191           88              82   394
# Nova Scotia                 129        148           73             114   464
# Nunavut                      12         35           23               9    79
# Ontario                     326        635          520             345  1826
# Prince Edward Island         36        118           22              35   211
# Quebec                      161        232          197             191   781
# ...

# %% [markdown]
# # EXAMPLE 3.2.

# %%
# If we define the aggfunc attribute, we must also define the values attribute (The default aggregate function is countt
# We will count all OrderIDs, for each 'Customer Segment' in each 'Province'
pd.crosstab(orders_data['Province'], orders_data['Customer Segment'], 
            margins=True, values=orders_data['OrderID'], aggfunc='count')
# Out:
# Customer Segment       Consumer  Corporate  Home Office  Small Business   All
# Province
# Alberta                     214        276          167             208   865
# British Columbia            191        415          298             222  1126
# Manitoba                    201        310          160             122   793
# New Brunswick                91         86           84              62   323
# Newfoundland                 20         30           14              18    82
# Northwest Territories        33        191           88              82   394
# Nova Scotia                 129        148           73             114   464
# Nunavut                      12         35           23               9    79
# Ontario                     326        635          520             345  1826
# Prince Edward Island         36        118           22              35   211
# Quebec                      161        232          197             191   781
# ...

# %% [markdown]
# # EXAMPLE 3.3.

# %%
# We will caluculate the average 'Sales' for each 'Customer Segment' in each 'Province'
pd.crosstab(orders_data['Province'], orders_data['Customer Segment'], 
            margins=True, values=orders_data['Sales'], aggfunc='mean')
# Out:
# Customer Segment          Consumer    Corporate  Home Office  Small Business  \
# Province
# Alberta                2359.352114  1797.410339  1406.932246     2254.073077
# British Columbia       1743.093859  1755.606918  1691.682310     1473.552514
# Manitoba               1444.404808  1986.939081  1558.913466     1779.886443
# New Brunswick          3387.418385  1743.173424  1714.455524     1323.052774
# Newfoundland           1290.455150  1221.474267  1170.711643     1337.820750
# Northwest Territories  2052.510621  1976.408073  2204.625398     1970.896366
# Nova Scotia            1664.900868  1529.543628  2786.788473     1518.852061
# Nunavut                2271.586667  1742.229000   997.452978      577.556667
# Ontario                1478.099014  1751.318412  1811.414706     1528.490906
# Prince Edward Island   1554.333444  1822.573568  2004.886000     2693.030657
# Quebec                 2082.320233  1996.559045  2093.104754     1567.529777
# ...

# %% [markdown]
# # LAB #2
# # Using crosstab () over data frame 'orders_data' calculate:
# # STEP 1: Average sales value for 'Province' and 'Product Category' columns
# # STEP 2: Sales amount for 'Province' and 'Product Category' columns
